# %%
import pickle
import pandas as pd 

import numpy as np

# %% [markdown]
# ## Fig Supp 8d

# %%
figdir = '../fig2_supp9b_varying_spot_sz/'

# %%
spa_celltype_key='cell_type'

dataset = 'Moffitt2018'

scrna_cluster_key = "Cell class (determined from clustering of all cells)"

deconv_dir = figdir + dataset + '/deconv/'
metrics_dir = figdir + dataset + '/metrics/'


N = 50
nneigh = 10
nbdswaps = 2
par_lambda_curr = 0.1
# par_eta1_curr = 10.0
kernel3d_bw_slices_curr = 8
bandwidth_curr = 0.01
n_spatial_neigh_curr = 10
mode_nbd = 'variabletranscr'
gtalign = False # if True, use GT alignment 
aligntool = 'moscot'
key_name = 'linear_0'
num_augment = '20'
mode_nbd = 'variabletranscr'
augment = True
mode = 'multislice'
sc_type = 'sc'


all_algos = {}

N_spot = [10, 25, 50, 75, 100]
for N_curr in N_spot:
    partesting_str =     '_partesting_' + 'parlambda_' + str(par_lambda_curr) +   '_parbw_' + str(bandwidth_curr) +  '_nbdtype_' + mode_nbd + '_gtalign_' + str(gtalign) + '_augment_' + str(augment) + '_kernel3d_bw_slices_' + str(kernel3d_bw_slices_curr) + '_num_augment_' + str(num_augment) + '_realalign_' + str(aligntool) 
    res_file = 'metrics_' + mode + '_' + mode_nbd + '_sptsz_' + str(N_curr)  + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + partesting_str +'_' + sc_type + '_sim.pickle'
    print(res_file)
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_sc_ms = pickle.load(handle)
    all_algos['SpaDecoder-' + 'SptSz-' + str(N_curr)] = metrics_sc_ms


## CARD
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_CARD.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_card = pickle.load(handle)
    metrics_card = metrics_card['linear_0']
    all_algos['CARD-' + 'SptSz-' + str(N_curr)] = metrics_card


## Cell2location
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_cell2location_dec2025_fig2_3k.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_cell2loc = pickle.load(handle)
    metrics_cell2loc = metrics_cell2loc['linear_0']
    all_algos['Cell2location-' + 'SptSz-' + str(N_curr)] = metrics_cell2loc

# Tangram 
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_tangram.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_tangram = pickle.load(handle)
    metrics_tangram = metrics_tangram['linear_0']
    all_algos['Tangram-' + 'SptSz-' + str(N_curr)] = metrics_tangram

# Tangram-sc
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_tangramsc.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_tangramsc = pickle.load(handle)
    metrics_tangramsc = metrics_tangramsc['linear_0']
    all_algos['Tangramsc-' + 'SptSz-' + str(N_curr)] = metrics_tangramsc



result_metrics = ['orig_rmse_avg',  'avg_corr_pe_avg', 'avg_jsd_avg']
col_names = result_metrics.copy()
col_names.extend(['algo'])
res_df = pd.DataFrame(columns=col_names)
idx = 0



for algo_name, algo_res in all_algos.items():
    real_samp = list(algo_res.keys())
    # sim_samp = metrics_sc_ms[entry][real_samp[0]].keys()
    for real_samp_name in real_samp:

        tmp_df = algo_res[real_samp_name].loc[result_metrics,:].T
        tmp_df['algo'] = algo_name.split('-')[0]
        tmp_df['sample'] = real_samp_name
        tmp_df['dataset'] = '-'.join(algo_name.split('-')[1:])
        res_df = pd.concat([res_df,tmp_df])


        
# res_df['dataset'] = 'Moffitt2018'
# Out:
# metrics_multislice_variabletranscr_sptsz_10_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_25_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_50_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_75_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_100_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# /tmp/ipykernel_1065825/69175815.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/69175815.py:94: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df = pd.concat([res_df,tmp_df])

# %%
to_plot = ['SpaDecoder', 'CARD', 'Cell2location', 'Tangram', 'Tangramsc']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def grouped_barplot(df, group_col, category_col, group_order, algo_order, value_col, save_path=None, xlabel="Groups", ylabel="Value", title="Grouped Bar Plot"):
    """
    Creates a grouped barplot where one column indicates the group, and another column represents categories within the group.
    The mean value is plotted as the height of the bars, and the standard deviation is used for error bars.

    Parameters:
    - df: Input DataFrame with values.
    - group_col: Column name representing groups.
    - category_col: Column name representing categories within groups.
    - value_col: Column name containing the values to be plotted.
    - xlabel: Label for the x-axis.
    - ylabel: Label for the y-axis.
    - title: Plot title.
    """

    # Compute mean and standard deviation for each (group, category) combination
    summary_df = df.groupby([group_col, category_col])[value_col].agg(['mean', 'min','max']).reset_index()

    # Handle NaN standard deviation values by replacing them with 0
    # summary_df['std'] = summary_df['std'].fillna(0)

    # Get unique groups and categories
    groups = group_order #summary_df[group_col].unique()
    categories = algo_order #summary_df[category_col].unique()

    # Define bar width and spacing
    bar_width = 0.01  # Width of each bar
    group_spacing = 0.01  # Space between groups
    x = np.arange(len(groups)) * (len(categories) * bar_width + group_spacing)

    fig, ax = plt.subplots(figsize=(18, 6))

    # Plot bars for each category
    for i, category in enumerate(categories):
        subset = summary_df[summary_df[category_col] == category].copy()
        subset[group_col] = pd.Categorical(subset[group_col], categories=group_order, ordered=True)
        subset = subset.sort_values(by=group_col)
        
        x_positions = x + i * bar_width
        means = subset['mean'].values
        # errors = subset['std'].values  # Standard deviation as error bars
        y_err = np.stack([subset['mean'].values - subset['min'].values, subset['max'].values - subset['mean'].values])
        # print(errors)
        # print(x_positions)
        # print(means)
        ax.bar(
            x_positions,
            means,
            bar_width,
            yerr=y_err,
            capsize=5,
            label=category
        )


        # Annotate each bar with its mean value
        for xpos, mean, err in zip(x_positions, means, y_err.T):
            # Adjust the offset (0.01) as needed for clarity.
            ax.text(xpos, mean + err[1] + 0.001, f'{mean:.3f}', ha='center', va='bottom', fontsize=24)


    # Customize x-axis
    ax.set_xticks(x + bar_width * (len(categories) - 1) / 2)
    ax.set_xticklabels(groups, rotation=0, fontsize=32)
    ax.tick_params(axis='y', labelsize=32)

    # Add labels, title, and legend
    ax.set_xlabel(xlabel, fontsize=32)
    ax.set_ylabel(ylabel, fontsize=32)
    ax.set_title(title, fontsize=32)
    ax.legend(title="Methods", fontsize=32, title_fontsize=32,loc='upper left', bbox_to_anchor=(1.02, 1))
    # ax.tick_params(axis='x', labelrotation=45)
    # Adjust layout and show plot
    plt.tight_layout()
    if save_path is not None:
        fig.savefig(save_path, dpi=1200, bbox_inches='tight')
    plt.show()



# df = pd.DataFrame(data)
# dataset_newname = {  'Moffitt2018':'Moffitt2018','Choi2023':'Choi2023',# 'dataset3_seqfishpluscai':'Eng2019No.2', 
#                     # 'dataset4_seqfishpluscai':'Eng2019',  'dataset5_starmap_mousevisualcortex':'Wang2018', 
#                     'Haviv2025':'Haviv2025'}
dataset_name = 'Moffitt2018'
dataset = ['SptSz-10', 'SptSz-25', 'SptSz-50', 'SptSz-75', 'SptSz-100']
    #    'Choi2023-Swap2','Choi2023-Swap5',  'Choi2023-Swap10','Choi2023-Swap20', 'Choi2023-Swap50', 
    #    'Haviv2025-Swap2', 'Haviv2025-Swap5', 'Haviv2025-Swap10', 'Haviv2025-Swap20', 'Haviv2025-Swap50']
result_metric_newname = {'orig_rmse_avg':'RMSE','avg_corr_pe_avg':'Aver Corr','avg_jsd_avg':'Aver JSD'}

# Plot using the function
# for metric in result_metrics:
#     grouped_barplot(res_df3, group_col="dataset", category_col="algo", group_order=list(dataset_newname.values()),algo_order=list(all_algos.keys()), value_col=metric,xlabel='Methods Across Datasets',ylabel=result_metric_newname[metric],title=result_metric_newname[metric] + ' Metric')

res_df_tmp = res_df[res_df['dataset'].isin(dataset)]
res_df_tmp = res_df_tmp.reset_index(drop=True)
res_df_tmp['dataset'] = res_df_tmp['dataset'].astype('str').str.split('-').str[1]
dataset = ['SptSz-10', 'SptSz-25', 'SptSz-50', 'SptSz-75', 'SptSz-100']
for metric in result_metrics:
    grouped_barplot(res_df_tmp, group_col="dataset", category_col="algo", group_order=dataset,algo_order=to_plot, save_path=figdir + metric + '_Moffitt2018_jan2026.pdf',value_col=metric,xlabel='Datasets',ylabel=result_metric_newname[metric],title=dataset_name + ' ' + result_metric_newname[metric] + ' Deconvolution Across Spot Size ')
    # plt.savefig(*args

# %% [markdown]
# ## Choi

# %%
# spa_celltype_key='cell_type'

dataset = 'Choi2023'

# scrna_cluster_key = "Cell class (determined from clustering of all cells)"

deconv_dir = figdir + dataset + '/deconv/'
metrics_dir = figdir + dataset + '/metrics/'


N = 50
nneigh = 10
nbdswaps = 2
par_lambda_curr = 0.1
# par_eta1_curr = 10.0
kernel3d_bw_slices_curr = 8
bandwidth_curr = 0.01
n_spatial_neigh_curr = 10
mode_nbd = 'variabletranscr'
gtalign = False # if True, use GT alignment 
aligntool = 'moscot'
key_name = 'linear_0'
num_augment = '20'
mode_nbd = 'variabletranscr'
augment = True
mode = 'multislice'
sc_type = 'sc'


all_algos = {}

N_spot = [10, 25, 50, 75, 100]
for N_curr in N_spot:
    partesting_str =     '_partesting_' + 'parlambda_' + str(par_lambda_curr) +   '_parbw_' + str(bandwidth_curr) +  '_nbdtype_' + mode_nbd + '_gtalign_' + str(gtalign) + '_augment_' + str(augment) + '_kernel3d_bw_slices_' + str(kernel3d_bw_slices_curr) + '_num_augment_' + str(num_augment) + '_realalign_' + str(aligntool) 
    res_file = 'metrics_' + mode + '_' + mode_nbd + '_sptsz_' + str(N_curr)  + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + partesting_str +'_' + sc_type + '_sim.pickle'
    print(res_file)
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_sc_ms = pickle.load(handle)
    all_algos['SpaDecoder-' + 'SptSz-' + str(N_curr)] = metrics_sc_ms


## CARD
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_CARD.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_card = pickle.load(handle)
    metrics_card = metrics_card['linear_0']
    all_algos['CARD-' + 'SptSz-' + str(N_curr)] = metrics_card


## Cell2location
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_cell2location_dec2025_fig2_3k.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_cell2loc = pickle.load(handle)
    metrics_cell2loc = metrics_cell2loc['linear_0']
    all_algos['Cell2location-' + 'SptSz-' + str(N_curr)] = metrics_cell2loc

# Tangram 
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_tangram.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_tangram = pickle.load(handle)
    metrics_tangram = metrics_tangram['linear_0']
    all_algos['Tangram-' + 'SptSz-' + str(N_curr)] = metrics_tangram

# Tangram-sc
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_tangramsc.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_tangramsc = pickle.load(handle)
    metrics_tangramsc = metrics_tangramsc['linear_0']
    all_algos['Tangramsc-' + 'SptSz-' + str(N_curr)] = metrics_tangramsc



result_metrics = ['orig_rmse_avg',  'avg_corr_pe_avg', 'avg_jsd_avg']
col_names = result_metrics.copy()
col_names.extend(['algo'])
res_df = pd.DataFrame(columns=col_names)
idx = 0



for algo_name, algo_res in all_algos.items():
    real_samp = list(algo_res.keys())
    # sim_samp = metrics_sc_ms[entry][real_samp[0]].keys()
    for real_samp_name in real_samp:

        tmp_df = algo_res[real_samp_name].loc[result_metrics,:].T
        tmp_df['algo'] = algo_name.split('-')[0]
        tmp_df['sample'] = real_samp_name
        tmp_df['dataset'] = '-'.join(algo_name.split('-')[1:])
        res_df = pd.concat([res_df,tmp_df])


        
# res_df['dataset'] = 'Moffitt2018'
# Out:
# metrics_multislice_variabletranscr_sptsz_10_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_25_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_50_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_75_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_100_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_augment_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# /tmp/ipykernel_1065825/4258133469.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/4258133469.py:94: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df = pd.concat([res_df,tmp_df])

# %%
# df = pd.DataFrame(data)
# dataset_newname = {  'Moffitt2018':'Moffitt2018','Choi2023':'Choi2023',# 'dataset3_seqfishpluscai':'Eng2019No.2', 
#                     # 'dataset4_seqfishpluscai':'Eng2019',  'dataset5_starmap_mousevisualcortex':'Wang2018', 
#                     'Haviv2025':'Haviv2025'}
dataset_name = 'Choi2023'
dataset = ['SptSz-10', 'SptSz-25', 'SptSz-50', 'SptSz-75', 'SptSz-100']
    #    'Choi2023-Swap2','Choi2023-Swap5',  'Choi2023-Swap10','Choi2023-Swap20', 'Choi2023-Swap50', 
    #    'Haviv2025-Swap2', 'Haviv2025-Swap5', 'Haviv2025-Swap10', 'Haviv2025-Swap20', 'Haviv2025-Swap50']
result_metric_newname = {'orig_rmse_avg':'RMSE','avg_corr_pe_avg':'Aver Corr','avg_jsd_avg':'Aver JSD'}

# Plot using the function
# for metric in result_metrics:
#     grouped_barplot(res_df3, group_col="dataset", category_col="algo", group_order=list(dataset_newname.values()),algo_order=list(all_algos.keys()), value_col=metric,xlabel='Methods Across Datasets',ylabel=result_metric_newname[metric],title=result_metric_newname[metric] + ' Metric')

res_df_tmp = res_df[res_df['dataset'].isin(dataset)]
res_df_tmp = res_df_tmp.reset_index(drop=True)
res_df_tmp['dataset'] = res_df_tmp['dataset'].astype('str').str.split('-').str[1]
dataset = ['SptSz-10', 'SptSz-25', 'SptSz-50', 'SptSz-75', 'SptSz-100']
for metric in result_metrics:
    grouped_barplot(res_df_tmp, group_col="dataset", category_col="algo", group_order=dataset,algo_order=to_plot, save_path=figdir + metric + '_' + dataset_name + '_jan2026.pdf',value_col=metric,xlabel='Datasets',ylabel=result_metric_newname[metric],title=dataset_name + ' ' + result_metric_newname[metric] + ' Deconvolution Across Spot Size ')
    # plt.savefig(*args

# %% [markdown]
# ## Haviv2025

# %%
spa_celltype_key='cell_type'

dataset = 'Haviv2025'

# scrna_cluster_key = "Cell class (determined from clustering of all cells)"

deconv_dir = figdir + dataset + '/deconv/'
metrics_dir = figdir + dataset + '/metrics/'


N = 50
nneigh = 10
nbdswaps = 2
par_lambda_curr = 0.1
# par_eta1_curr = 10.0
kernel3d_bw_slices_curr = 8
bandwidth_curr = 0.01
n_spatial_neigh_curr = 10
mode_nbd = 'variabletranscr'
gtalign = False # if True, use GT alignment 
aligntool = 'moscot'
key_name = 'linear_0'
num_augment = '20'
mode_nbd = 'variabletranscr'
augment = True
mode = 'multislice'
sc_type = 'sc'


all_algos = {}

N_spot = [10, 25, 50, 75, 100]
for N_curr in N_spot:
    partesting_str =     '_partesting_' + 'parlambda_' + str(par_lambda_curr) +   '_parbw_' + str(bandwidth_curr) +  '_nbdtype_' + mode_nbd + '_gtalign_' + str(gtalign) + '_' + str(augment) + '_kernel3d_bw_slices_' + str(kernel3d_bw_slices_curr) + '_num_augment_' + str(num_augment) + '_realalign_' + str(aligntool) 
    res_file = 'metrics_' + mode + '_' + mode_nbd + '_sptsz_' + str(N_curr)  + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + partesting_str +'_' + sc_type + '_sim.pickle'
    print(res_file)
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_sc_ms = pickle.load(handle)
    all_algos['SpaDecoder-' + 'SptSz-' + str(N_curr)] = metrics_sc_ms


## CARD
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_CARD.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_card = pickle.load(handle)
    metrics_card = metrics_card['linear_0']
    all_algos['CARD-' + 'SptSz-' + str(N_curr)] = metrics_card


## Cell2location
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_cell2location_dec2025_fig2_3k.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_cell2loc = pickle.load(handle)
    metrics_cell2loc = metrics_cell2loc['linear_0']
    all_algos['Cell2location-' + 'SptSz-' + str(N_curr)] = metrics_cell2loc

# Tangram 
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_tangram.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_tangram = pickle.load(handle)
    metrics_tangram = metrics_tangram['linear_0']
    all_algos['Tangram-' + 'SptSz-' + str(N_curr)] = metrics_tangram

# Tangram-sc
for N_curr in N_spot:
    res_file = 'metrics_st1_sptsz_' + str(N_curr) + '_nneigh_' + str(nneigh) + '_nbdswaps_' + str(nbdswaps) + '_tangramsc.pickle'
    with open(metrics_dir + res_file, 'rb') as handle:
        metrics_tangramsc = pickle.load(handle)
    metrics_tangramsc = metrics_tangramsc['linear_0']
    all_algos['Tangramsc-' + 'SptSz-' + str(N_curr)] = metrics_tangramsc



result_metrics = ['orig_rmse_avg',  'avg_corr_pe_avg', 'avg_jsd_avg']
col_names = result_metrics.copy()
col_names.extend(['algo'])
res_df = pd.DataFrame(columns=col_names)
idx = 0



for algo_name, algo_res in all_algos.items():
    real_samp = list(algo_res.keys())
    # sim_samp = metrics_sc_ms[entry][real_samp[0]].keys()
    for real_samp_name in real_samp:

        tmp_df = algo_res[real_samp_name].loc[result_metrics,:].T
        tmp_df['algo'] = algo_name.split('-')[0]
        tmp_df['sample'] = real_samp_name
        tmp_df['dataset'] = '-'.join(algo_name.split('-')[1:])
        res_df = pd.concat([res_df,tmp_df])


        
# res_df['dataset'] = 'Moffitt2018'
# Out:
# metrics_multislice_variabletranscr_sptsz_10_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_25_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_50_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_75_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# metrics_multislice_variabletranscr_sptsz_100_nneigh_10_nbdswaps_2_partesting_parlambda_0.1_parbw_0.01_nbdtype_variabletranscr_gtalign_False_True_kernel3d_bw_slices_8_num_augment_20_realalign_moscot_sc_sim.pickle
# /tmp/ipykernel_1065825/1573567821.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:38: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_sc_ms = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:46: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_card = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:63: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangram = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:71: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   metrics_tangramsc = pickle.load(handle)
# /tmp/ipykernel_1065825/1573567821.py:94: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   res_df = pd.concat([res_df,tmp_df])

# %%
# df = pd.DataFrame(data)
# dataset_newname = {  'Moffitt2018':'Moffitt2018','Choi2023':'Choi2023',# 'dataset3_seqfishpluscai':'Eng2019No.2', 
#                     # 'dataset4_seqfishpluscai':'Eng2019',  'dataset5_starmap_mousevisualcortex':'Wang2018', 
#                     'Haviv2025':'Haviv2025'}
dataset_name = 'Haviv2025'
dataset = ['SptSz-10', 'SptSz-25', 'SptSz-50', 'SptSz-75', 'SptSz-100']
    #    'Choi2023-Swap2','Choi2023-Swap5',  'Choi2023-Swap10','Choi2023-Swap20', 'Choi2023-Swap50', 
    #    'Haviv2025-Swap2', 'Haviv2025-Swap5', 'Haviv2025-Swap10', 'Haviv2025-Swap20', 'Haviv2025-Swap50']
result_metric_newname = {'orig_rmse_avg':'RMSE','avg_corr_pe_avg':'Aver Corr','avg_jsd_avg':'Aver JSD'}

# Plot using the function
# for metric in result_metrics:
#     grouped_barplot(res_df3, group_col="dataset", category_col="algo", group_order=list(dataset_newname.values()),algo_order=list(all_algos.keys()), value_col=metric,xlabel='Methods Across Datasets',ylabel=result_metric_newname[metric],title=result_metric_newname[metric] + ' Metric')

res_df_tmp = res_df[res_df['dataset'].isin(dataset)]
res_df_tmp = res_df_tmp.reset_index(drop=True)
res_df_tmp['dataset'] = res_df_tmp['dataset'].astype('str').str.split('-').str[1]
dataset = ['SptSz-10', 'SptSz-25', 'SptSz-50', 'SptSz-75', 'SptSz-100']
for metric in result_metrics:
    grouped_barplot(res_df_tmp, group_col="dataset", category_col="algo", group_order=dataset,algo_order=to_plot, save_path=figdir + metric + '_' + dataset_name + '_jan2026.pdf',value_col=metric,xlabel='Datasets',ylabel=result_metric_newname[metric],title=dataset_name + ' ' + result_metric_newname[metric] + ' Deconvolution Across Spot Size ')
    # plt.savefig(*args
